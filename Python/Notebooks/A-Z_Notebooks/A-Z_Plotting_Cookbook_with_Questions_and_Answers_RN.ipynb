# %% [markdown]
# ### Plotting A-Z
#
# # Python Plotting Cookbook with Questions and Answers
#
# <br>
# <img src = "images/logo.jpg" width="100" align="left">
#
# <br><br><br><br>Ram Narasimhan

# %% [markdown]
# # About the Plotting Cookbook
#
# I have created this "Cookbook" so that new learners can use it as a reference for a few simple plotting tasks, using Python.
#
# There are several plotting libraries. For this cookbook, I have limited it to 3: Matplotlib, Seaborn and Pandas.
#
# This Notebook is divided into multiple sections by concept.<br>
# Just refer to the Table of Contents and click the link to get your answers.

# %% [markdown]
# # Table of Contents

# %% [markdown]
# ## Part 1: Plotting Using Matplotlib
#
# - **P1.1 How to plot a histogram of one NUMERICAL Column?**
# - **P1.2 How to plot a scatter plot using Matplotlib?**
# - **P1.3 How to create a bar plot using Matplotlib? **
# - **P1.4 How to create a lineplot using Matplotlib? **
#
# - **P1.5 How to Save a Plot to a file? **
#
# <a href='#part1'>Go to Part 1</a>

# %% [markdown]
# ## Part 2: Plotting Using Pandas
#
# - **P2.1 How to plot a histogram of one NUMERICAL Column? **
# - **P2.2 How to create a bar plot of 2 columns? **
# - **P2.3 How to plot a scatter plot of 2 columns?**
# - **P2.4 How to create a line plot with more than one Y variable?**
# - **P2.5 How to Save a Plot to a file? **

# %% [markdown]
# ## Part 3: Plotting Using Seaborn
#
# - **P3.1 How to plot a histogram of one NUMERICAL Column? **
# - **P3.2 How to plot a scatter plot of 2 columns?**
# - **P3.3 How to create a bar plot of 2 columns? **
# - **P3.4 How to Save a Plot to a file? **

# %% [markdown]
# ## Part 4: Decorating your Plots (Aesthetics)
#
# - **P4.1 How to plot a histogram of one NUMERICAL Column? **
# - **P4.2 How to plot a scatter plot of 2 columns?**
# - **P4.3 How to create a bar plot of 2 columns? **
# - **P4.4 How to Save a Plot to a file? **

# %% [markdown]
# ----
# # <div class="alert-success">Solutions </div>
# # <div class="alert-success">  </div>
# # <div class="alert-success">  </div>
# ---

# %%
import numpy as np #a new module
import pandas as pd #we will see this more and more
import matplotlib.pyplot as plt #plotting module
import seaborn as sns # Seaborn for plotting and styling
sns.set(color_codes=True)

#shows the graphs in the Notebook itself. (INLINE)
# %matplotlib inline

# %% [markdown]
# ### Data Files
#
# For most of the tasks in this Cookbook, we will be using the following Data Frame. So let's create one with some dummy data to help understand the concepts and called it `df`.

# %%
df = pd.DataFrame({'Date': ['2/23/2019', '2/23/2019', '2/23/2019', '2/23/2019', '2/27/2019', '3/3/2019', '3/3/2019', '3/3/2019', '3/3/2019', '3/3/2019']
,'Time' :['9:01','13:22', '14:58', '17:31', '8:29', '11:11', '13:08', '9:01', '7:33', '14:29']
,'Col One' : ['Zero', 'One ', 'Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine']
,'Temp' : [21.9, 34.2, 28.0, 29.4, 12.0, 14.5, 40.9, 35.5, 23.2, 38.6]
,'Names' : ['John', 'Mary', 'John', 'Peter', 'Ali', 'Ravi', np.nan, np.nan, 'Mariam', 'Merry'] 
,'Pressure_psi' : [14.9, np.nan, 14.7, 14.669, 14.81, 14.73, 14.27, 14.9, 14.88, 14.71]})
    
df
# Out:
#         Date   Time Col One  Temp   Names  Pressure_psi
# 0  2/23/2019   9:01    Zero  21.9    John        14.900
# 1  2/23/2019  13:22    One   34.2    Mary           NaN
# 2  2/23/2019  14:58     Two  28.0    John        14.700
# 3  2/23/2019  17:31   Three  29.4   Peter        14.669
# 4  2/27/2019   8:29    Four  12.0     Ali        14.810
# 5   3/3/2019  11:11    Five  14.5    Ravi        14.730
# 6   3/3/2019  13:08     Six  40.9     NaN        14.270
# 7   3/3/2019   9:01   Seven  35.5     NaN        14.900
# 8   3/3/2019   7:33   Eight  23.2  Mariam        14.880
# 9   3/3/2019  14:29    Nine  38.6   Merry        14.710

# %% [markdown]
# <a id='#part1'></a>

# %% [markdown]
#
# # Part 1: Plotting with Matplotlib

# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %%
import numpy as np
vec = np.random.beta(3,10, 10000)
plt.hist(vec)
# Out:
# (array([  7.42000000e+02,   2.50500000e+03,   2.86000000e+03,
#           2.06800000e+03,   1.13700000e+03,   4.84000000e+02,
#           1.53000000e+02,   4.40000000e+01,   6.00000000e+00,
#           1.00000000e+00]),
#  array([ 0.00204572,  0.0844589 ,  0.16687208,  0.24928526,  0.33169844,
#          0.41411162,  0.49652481,  0.57893799,  0.66135117,  0.74376435,
#          0.82617753]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# To render plots in your Jupyter notebook, add the following:
#
# ```
# %matplotlib inline
#
# import matplotlib
# import numpy as np
# import matplotlib.pyplot as plt
#
# ```
# barplots, and histograms

# %% [markdown]
# ## Scatterplots using Matplotlib

# %%
plt.plot([2,4,6,8])
plt.ylabel('Twice the number')
plt.show()

# %% [markdown]
# Notice several things:
# - It plotted a line plot by default
# - Input was a List
# - Matplotlib assumed that the input list was Y values
# - x values start from 0, and go till 3

# %%
plt.plot([2,4,6,8], 'ro')
plt.ylabel('Twice the number')
plt.show()

# %% [markdown]
#     The default for `matplotlib` is a blue line "b-"

# %% [markdown]
# ### Now let's create a few scatterplots

# %%
import numpy as np
x = [1,2,3,4]
y = list(np.array(x)**2)
plt.plot(x,y, 'bo') #'go is for green dot'
plt.show()

# %% [markdown]
# The Axis is too tight. Let's give it some room.
# The format for axis is `[xmin, xmax, ymin, ymax] `

# %%
plt.plot(x,y, 'bo')
plt.axis([0, 6, 0, 20]) # set the axis limits
plt.show()

# %%
# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)

#You can plot multiple series in one plot, just call x, y and shape over and over.
# red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', 
         t, t**2, 'bs', 
         t, t**3, 'g^')
plt.show()

# %% [markdown]
# ### Color short cuts in `matplotlib`
#  - `r--` a dashed red line
#  - `bs` Blue Squares
#  - `g^` green triangles

# %% [markdown]
# # Making line charts, scatterplots, barplots, and histograms

# %% [markdown]
# # Part 2: Plotting with Pandas

# %% [markdown]
# - **P2.1 How to plot a histogram of one NUMERICAL Column? **

# %%
df['Temp'].hist(bins=5)

# %% [markdown]
# - **P2.2 How to plot a scatter plot in Pandas, using 1 column as x and the other as y?**

# %%
df.plot(x='Pressure_psi', y='Temp', kind='scatter', color='red')
plt.title('Pressure_psi vs TemP');

# %% [markdown]
# - **P2.3 How to create a bar plot of 2 columns? **

# %%
df.plot(x='Pressure_psi', y='Temp', kind='bar'); #note that the x-axis is NOT sorted. Each is treated as a label

# %% [markdown]
# - **P2.4 How to plot two (or more) columns on the same plot?**

# %%
df[['Temp', 'Pressure_psi']].plot(style='o-', figsize=(12,4));

# %% [markdown]
# - **P2.5 How to include a legend in a Pandas plot? **

# %% [markdown]
# To include a legend, just add `legend=True`

# %%
fig, axes = plt.subplots(1, 2, figsize=(12,3)) #fig is common to both plots
# Each axes can be referred to by axes[0] or as axes[1]
df['Temp'].plot(ax=axes[0], title='No Legend')
df['Temp'].plot(legend=True, ax=axes[1], title='With Title');

# %%
df[['Temp', 'Pressure_psi']].plot(style='-', subplots=True, figsize=(12,4));

# %% [markdown]
# - ** 9.5 How to Save a Plot to a file? **
#
# This is a two-step process. First, we store the Pandas plot to a variable. Once that is done, we can `get_figure` and then `savefig` that to a file.

# %% [markdown]
# ** Save a Pandas plot **
#
# If the Pandas plot has been stored to a variable, then we first need to `get_figure()` and only then savefig() will do the job.
#
# Gory Details: This is because `df.plot()` saves it to an `AxesSubplot` type of object. Those cannot be directly saved. We first get the parent figure for the `AxesSubplot`, and then we can easily save it using `savefig`

# %%
pandas_plot = df.plot() # save it to a variable for ease of referring to it
fig = pandas_plot.get_figure()
fig.savefig ("Pandas.png")

# %% [markdown]
# - **9.6 Creating Multiple Plots side-by-side, and changing markers & plot types**

# %%
fig, axes = plt.subplots(1, 4, figsize=(12,3)) #fig is common to all plots. Each one can be referred to by axes[0],...,axes[3]
df.plot(style='o', ax=axes[0]);
df.plot(style='.', ax=axes[1]);
df.plot(style='-', ax=axes[2]);
df['Temp'].plot(style='-', kind='bar', ax=axes[3]);

# %% [markdown]
# **Important to Note** When you plot a bar plot, notice that in the x-axis, time duration is NOT show visually. Each bar is simply treated as a 'label' and the distance between every 2 bars in the same, no mater the time duration. In contast, in all the other plots above, time duration is explicitly shown.

# %% [markdown]
# - ** 9.7 How to Add a title to a plot? **

# %%
df.plot(figsize=(10,3))
plt.title("matplotlib xy line plot");

# %%
x = [1,3,3,4,1,4,1,2,5,5,7,7,4,2,5,6,4,3,3,6,8,9]
plt.hist(x);

# %%
#Data
fruits = ['Apple', 'Banana', 'Orange', 'Kiwi']
x_pos = [0,1,2,3]
count = [4,8,6,4]

#plotting
plt.bar(x_pos, count, align='center', alpha=0.5)
plt.xticks(y_pos, fruits)
plt.ylabel('Number of fruit')
plt.title('Fruit Salad')
 
plt.show()

# %% [markdown]
# ## Part 3: Plotting Using Seaborn
#
# - ** 9.1 How to plot a histogram of one NUMERICAL Column? **

# %% [markdown]
# - **9.2 How to plot a scatter plot of 2 columns?**

# %% [markdown]
# - ** 9.3 How to create a bar plot of 2 columns? Using Seaborn**

# %% [markdown]
# - ** 9.4 How to Save a Seaborn Plot to a file? **

# %% [markdown]
# ## How to save a Seaborn plot?
#
# This requires one extra step. First, save the plot to a variable name.<br>
# But we only know how to plot `fig.savefig()`. So we simply get hold of the figure, and then it works.

# %%
sns_plot = sns.distplot(df["Temp"], kde=False)

fig = sns_plot.get_figure() #now fig is available to Matplotlib
fig.savefig('saved_seaborn_hist.png') #save any seaborn plot to a file name...
# Out:
# C:\Users\Ram\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# ## Part 4: More Advanced Plotting
#
# - ** P4.1 How to add TEXT annotations to your plots? **

# %% [markdown]
# # Working with `text()`

# %%
mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)

# the histogram of the data
n, bins, patches = plt.hist(x, 50, density=1, facecolor='g', alpha=0.75)


plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ')

#Add some text
plt.text(60, .025, r'$\mu=100,\ \sigma=15$') # This is NEW. Note how it works


plt.axis([40, 160, 0, 0.03])
plt.grid(True)

# %% [markdown]
#  - The text() command can be used to add text in an arbitrary location
#  - The xlabel(), ylabel() and title() are used to add text in the indicated locations.
#
#  Example:
#
# ```
# plt.xlabel('Smarts')
# plt.ylabel('Probability')
#
# plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
#
# ```

# %% [markdown]
# Can decorate the `text()` with a few parameters for aesthetics.
# ```
# t = plt.xlabel('my data', fontsize=14, color='red')
# ```

# %%
t = plt.xlabel('my data', fontsize=14, color='red')

# %% [markdown]
# **P4.2 How to Work with Multiple Plots?**

# %% [markdown]
# The subplot() command specifies **numrows, numcols, fignum** where `fignum` ranges from 1 to `numrows x numcols`.

# %%
plt.subplot(2,1,1)
plt.plot(x, y, 'bo', x, y, 'k') # 'k' is for a black line

plt.subplot(2,1,2)
plt.plot(x, np.sin(x), 'r--')
plt.show()

# %% [markdown]
# **P4.3 Provide a detailed example of how `figure() ` and `plt.subplot()` works**

# %%
plt.figure(1)                # the first figure
plt.subplot(211)             # the first subplot in the first figure
plt.plot([1, 2, 3])
plt.subplot(212)             # the second subplot in the first figure
plt.plot([4, 5, 6], 'ro')


plt.figure(2)                # a second figure
plt.plot([9, 9, 3], 'g')          # creates a subplot(111) by default

plt.figure(1)                # figure 1 current; subplot(212) still current
plt.subplot(211)             # make subplot(211) in figure1 current
plt.title('Easy as 1, 2, 3') # subplot 211 title
# Out:
# C:\Users\Ram\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# Text(0.5,1,'Easy as 1, 2, 3')

# %% [markdown]
# You can create multiple figures by using multiple figure() calls with an increasing figure number.
